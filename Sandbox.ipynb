# %%
import pandas as pd
pd.read_csv('Data_Frame_Of_33145_Observed_Docking_Scores_And_Averages_And_Standard_Deviations_Of_Docking_Scores_Predicted_By_BNN_Based_On_Numbers_Of_Occurrences_Of_Substructures.csv')
# Out:
#        observed_response_value  average_of_predicted_response_values  \
# 0                    -0.547488                             -0.080341
# 1                     0.793782                             -0.823150
# 2                     0.306230                              0.190004
# 3                     0.644230                             -0.124254
# 4                    -0.931762                             -0.439488
# ...                        ...                                   ...
# 33140                 0.785064                              0.350801
# 33141                 0.332385                              0.200458
# 33142                 0.235143                             -0.133104
# 33143                -0.661497                             -0.464037
# 33144                -1.128929                             -0.294360
#
#        standard_deviation_of_predicted_response_values
# 0                                             0.860116
# ...
