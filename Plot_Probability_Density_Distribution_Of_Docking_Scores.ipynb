# %%
import pandas as pd
df = pd.read_csv(filepath_or_buffer = 'Data_Frame_Of_Docking_Scores_And_SMILESs.csv')
df
# Out:
#          docking score                                             SMILES
# 0              -12.086  c1cccc(c12)[nH]c(n2)[C@H](Cc3ccccc3)NC(=O)CCCc...
# 1              -11.969  c1sccc1C(=O)Nc(cccc2)c2C(=O)N3CCN(CC3)Cc4csc(n...
# 2              -11.944  Cc1cc(C)cc(c1)Nc2ccn(c(n2)=O)-c(c3-c4ccccc4)nc...
# 3              -11.897  O=C1CCCN1c(c(Cl)cc2)cc2C(=O)NN(C(=O)N3)C(=O)C3...
# 4              -11.863  c1cccc(c12)c(=O)n(-c3ccccc3)nc2C(=O)N(CC4)CC=C...
# ...                ...                                                ...
# 2121221          9.620  CN(C)C(=O)C1(CC1)C(=O)N(CC2)CCC2[C@@H](O3)CC[C...
# 2121222          9.654  COCCN(CCOC)C(=O)[C@H]1CCCN(C1)S(=O)(=O)c(cc2)c...
# 2121223          9.698              Cn1cc(Cl)cc1C(=O)NCC2(CCOCC2)N3CCCCC3
# 2121224         11.841  s1cccc1C(=O)N(CCC2)c(c23)cc(cc3)NC(=O)c4cc(C)c...
# 2121225         12.978  CCO[C@H](C)C(=O)N(C1)[C@@H](C(=O)OC(C)(C)C)Cn(...
#
# [2121226 rows x 2 columns]

# %%
import numpy as np
import seaborn as sns

series_of_docking_scores = df['docking score']
the_mean = np.mean(series_of_docking_scores)
standard_deviation = np.std(series_of_docking_scores)

the_Axes = sns.distplot(
    a = series_of_docking_scores,
    bins = 100,
    kde_kws = {"label": "KDE"},
    hist_kws = {"label": "Histogram"}
)
the_Axes.set(
    xlabel = "Docking Score",
    ylabel = "Probability Density",
    title = (
        "Probability Density Distribution Of Docking Scores"
        + f"\nNumber Of Observations = {df.shape[0]}, Mean = {the_mean}, Standard Deviation = {standard_deviation}"
    )
)
import matplotlib.pyplot as plt
plt.legend()
plt.savefig("Probability_Density_Distribution_Of_Docking_Scores.png")
plt.show()
# Out:
# C:\Users\Tom\AppData\Local\Temp\ipykernel_15700\1811229761.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   the_Axes = sns.distplot(
